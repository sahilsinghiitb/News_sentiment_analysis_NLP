# %%
import pandas as pd

# %%
df = pd.read_csv("/content/news_senti_data.csv",encoding='latin1')

# Preview data
df.head()
# Out:
#   Sentiment                                     News_statement
# 0   neutral  According to Gran , the company has no plans t...
# 1   neutral  Technopolis plans to develop in stages an area...
# 2  negative  The international electronic industry company ...
# 3  positive  With the new production plant the company woul...
# 4  positive  According to the company 's updated strategy f...

# %%
# !pip install --upgrade torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpu
# ...

# %%
import torch
print(torch.__version__)  # should be >= 1.10.0
# Out:
# 2.8.0+cpu

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline
import pandas as pd
from tqdm import tqdm

model_name = "ProsusAI/finbert"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

classifier = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)

# Apply to dataset
tqdm.pandas()
df["Predicted_Sentiment"] = df["News_statement"].progress_apply(
    lambda x: classifier(str(x), truncation=True)[0]['label'].lower()
)

print(df.head())
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:945: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/252 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/758 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# 100%|██████████| 4846/4846 [10:41<00:00,  7.55it/s]
#   Sentiment                                     News_statement  \
# 0   neutral  According to Gran , the company has no plans t...
# 1   neutral  Technopolis plans to develop in stages an area...
# 2  negative  The international electronic industry company ...
# 3  positive  With the new production plant the company woul...
# ...

# %%
df.head(100)
# Out:
#    Sentiment                                     News_statement  \
# 0    neutral  According to Gran , the company has no plans t...
# 1    neutral  Technopolis plans to develop in stages an area...
# 2   negative  The international electronic industry company ...
# 3   positive  With the new production plant the company woul...
# 4   positive  According to the company 's updated strategy f...
# ..       ...                                                ...
# 95  positive  Finnish financial group Aktia reports operatin...
# 96  positive  Finnish high technology provider Vaahto Group ...
# 97  positive  Net sales of Finnish food industry company L+Æ...
# 98  positive  An individual promotion also generated slightl...
# 99  positive  Biohit already services many current Genesis c...
#
#    Predicted_Sentiment
# 0              neutral
# 1              neutral
# 2             negative
# 3             positive
# 4             positive
# ..                 ...
# 95            positive
# ...

# %%
accuracy = (df["Sentiment"].str.lower() == df["Predicted_Sentiment"]).mean()
print(f"Accuracy: {accuracy:.2%}")
# Out:
# Accuracy: 88.94%
